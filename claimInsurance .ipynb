# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("insurance2.csv")
df.sample(4)
# Out:
#       age  sex     bmi  children  smoker  region      charges  insuranceclaim
# 266    40    1  19.800         1       1       2  17179.52200               1
# 943    19    1  22.610         0       0       1   1628.47090               0
# 838    35    0  23.465         2       0       0   6402.29135               0
# 1300   45    1  30.360         0       1       2  62592.87309               1

# %%
df.drop(['region'],axis=1,inplace=True)
df
# Out:
#       age  sex     bmi  children  smoker      charges  insuranceclaim
# 0      19    0  27.900         0       1  16884.92400               1
# 1      18    1  33.770         1       0   1725.55230               1
# 2      28    1  33.000         3       0   4449.46200               0
# 3      33    1  22.705         0       0  21984.47061               0
# 4      32    1  28.880         0       0   3866.85520               1
# ...   ...  ...     ...       ...     ...          ...             ...
# 1333   50    1  30.970         3       0  10600.54830               0
# 1334   18    0  31.920         0       0   2205.98080               1
# 1335   18    0  36.850         0       0   1629.83350               1
# 1336   21    0  25.800         0       0   2007.94500               0
# 1337   61    0  29.070         0       1  29141.36030               1
#
# [1338 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(df[['age','sex','bmi','children','smoker','charges']],df.insuranceclaim,test_size=0.2,random_state=25)

# %%
X_test.max()
# Out:
# age            64.00000
# sex             1.00000
# bmi            48.07000
# children        5.00000
# smoker          1.00000
# charges     48517.56315
# dtype: float64

# %%
X_train_scaled = X_train.copy()
X_train_scaled['age'] = X_train_scaled['age']/100
X_train_scaled['bmi'] = X_train_scaled['bmi']/49
X_train_scaled['children'] = X_train_scaled['children']/5
X_train_scaled['charges'] = X_train_scaled['charges'] / 48517.56315


X_test_scaled = X_test.copy()
X_test_scaled['age'] = X_test_scaled['age'] /100
X_test_scaled['bmi'] = X_test_scaled['bmi']/49
X_test_scaled['children'] = X_test_scaled['children']/5
X_test_scaled['charges'] = X_test_scaled['charges'] / 48517.56315

# %%
X_train_scaled
# Out:
#        age  sex       bmi  children  smoker   charges
# 629   0.44    0  0.794898       0.0       1  0.885936
# 556   0.46    1  0.682449       0.2       0  0.171785
# 427   0.18    0  0.595204       0.0       0  0.150950
# 1047  0.22    1  1.073061       0.2       1  0.917222
# 98    0.56    1  0.407143       0.0       1  0.461949
# ...    ...  ...       ...       ...     ...       ...
# 886   0.57    1  0.591327       0.0       1  0.561002
# 143   0.29    1  0.606837       0.4       0  0.374254
# 474   0.54    1  0.512245       0.6       1  0.523157
# 318   0.44    0  0.564184       0.0       0  0.152959
# 1156  0.19    1  0.915918       0.0       1  0.818729
#
# [1070 rows x 6 columns]

# %%
model = keras.Sequential([
    keras.layers.Dense(200,input_shape=(6,),activation='relu',kernel_initializer='ones',bias_initializer='zeros'),
    keras.layers.Dense(100,activation='tanh'),
    keras.layers.Dense(1,activation='sigmoid')  
])

model.compile(optimizer='adam',
             loss='binary_crossentropy',
              metrics=['accuracy']
              )
model.fit(X_train_scaled,y_train,epochs=1000)
# Out:
# Epoch 1/1000
# 34/34 [==============================] - 1s 4ms/step - loss: 0.7012 - accuracy: 0.5551
# Epoch 2/1000
# 34/34 [==============================] - 0s 4ms/step - loss: 0.6518 - accuracy: 0.6112
# Epoch 3/1000
# 34/34 [==============================] - 0s 4ms/step - loss: 0.6386 - accuracy: 0.6131
# Epoch 4/1000
# 34/34 [==============================] - 0s 4ms/step - loss: 0.6082 - accuracy: 0.6664
# Epoch 5/1000
# 34/34 [==============================] - 0s 4ms/step - loss: 0.5936 - accuracy: 0.6850
# Epoch 6/1000
# 34/34 [==============================] - 0s 5ms/step - loss: 0.5715 - accuracy: 0.7093
# Epoch 7/1000
# 34/34 [==============================] - 0s 5ms/step - loss: 0.5452 - accuracy: 0.7533
# Epoch 8/1000
# 34/34 [==============================] - 0s 5ms/step - loss: 0.5220 - accuracy: 0.7505
# Epoch 9/1000
# 34/34 [==============================] - 0s 5ms/step - loss: 0.5180 - accuracy: 0.7551
# Epoch 10/1000
# ...

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2570 - accuracy: 0.9179
# [0.25701427459716797, 0.9179104566574097]

# %%
model.predict(X_test_scaled)
# Out:
# 9/9 [==============================] - 0s 2ms/step
# array([[9.72525954e-01],
#        [3.56144875e-01],
#        [9.95495141e-01],
#        [9.99666989e-01],
#        [9.99996364e-01],
#        [9.99906480e-01],
#        [9.84964371e-01],
#        [3.77276778e-01],
#        [9.99998987e-01],
#        [9.70574737e-01],
#        [5.61051490e-03],
#        [1.75661102e-01],
#        [1.07605783e-02],
#        [9.99993920e-01],
#        [6.07136497e-03],
#        [3.79413903e-01],
#        [3.45760524e-01],
#        [9.99991775e-01],
#        [9.99925852e-01],
#        [9.99899089e-01],
#        [9.93780136e-01],
#        [8.58596712e-02],
#        [8.43329951e-02],
#        [9.99998629e-01],
#        [1.03987651e-02],
#        [9.58515942e-01],
#        [3.68090659e-01],
#        [9.99998987e-01],
#        [9.99908090e-01],
#        [9.96158242e-01],
#        [2.74189971e-02],
#        [9.99932587e-01],
#        [9.79854345e-01],
#        [8.92878845e-02],
#        [4.63315755e-01],
# ...
